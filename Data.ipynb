# %%
import wrds
import pandas as pd

# %%
wrds_db = wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# pgpass file created at C:\Users\fumas\AppData\Roaming\postgresql\pgpass.conf
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
# downloading and extracting list of developed countries
countries = pd.read_excel(
    'https://raw.githubusercontent.com/bkelly-lab/jkp-data/main/data/country_classification.xlsx'
)
countries_rel = countries[countries['msci_development'] == 'developed']['excntry'].tolist()

# %%
countries_rel
# Out:
# ['USA',
#  'JPN',
#  'HKG',
#  'GBR',
#  'CAN',
#  'AUS',
#  'DEU',
#  'FRA',
#  'SWE',
#  'CHE',
#  'SGP',
#  'ITA',
#  'ESP',
#  'ISR',
#  'NLD',
#  'NOR',
#  'BEL',
#  'DNK',
#  'FIN',
#  'NZL',
#  'AUT',
#  'IRL',
#  'PRT']

# %%
# Download JKP data from USA
sql_query = f"""
    SELECT id, eom, excntry, gvkey, permno, size_grp, me, ret_exc_lead1m
    FROM contrib.global_factor
    WHERE common=1 and exch_main=1 and primary_sec=1 and obs_main=1 and
    excntry='USA'
"""

data = wrds_db.raw_sql(sql_query)

# %%
# downloading and extracting list of characteristics
chars = pd.read_excel('https://raw.githubusercontent.com/bkelly-lab/jkp-data/main/data/factor_details.xlsx')
chars_rel = chars[chars['abr_jkp'].notna()]['abr_jkp'].tolist()

# %%
data.tail()
# Out:
#              id         eom excntry   gvkey   permno size_grp              me  \
# 262867  93436.0  2024-08-31     USA  184996  93436.0     mega    684004.37235
# 262868  93436.0  2024-09-30     USA  184996  93436.0     mega   839047.425659
# 262869  93436.0  2024-10-31     USA  184996  93436.0     mega   802033.510593
# 262870  93436.0  2024-11-30     USA  184996  93436.0     mega  1107984.321356
# 262871  93436.0  2024-12-31     USA  184996  93436.0     mega  1296350.618644
#
#         ret_exc_lead1m
# 262867        0.217323
# 262868       -0.048932
# 262869        0.377514
# 262870        0.166345
# 262871            <NA>

# %%
sql_query = f"""
    SELECT id, eom, excntry, gvkey, permno, size_grp, me, {', '.join(map(str, chars_rel))}
    FROM contrib.global_factor
    WHERE common=1 and exch_main=1 and primary_sec=1 and obs_main=1 and
    excntry = 'USA'
"""
data = wrds_db.raw_sql(sql_query)
data.to_csv(f'USA.csv')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\fumas\Documents\Travail\EDHEC\Cours\M2 - Nice\S1\Advanced Fixed Income & Credit\FIN2764\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\fumas\Documents\Travail\EDHEC\Cours\M2 - Nice\S1\Advanced Fixed Income & Credit\FIN2764\.venv\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# ...
